# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 3-MODUL. MA’LUMOTLARGA ISHLOV BERISH
#
# ### 3.1 Fayllar bilan ishlash

# %% [markdown]
# ### Web fayllar bilan ishlash
# #### `read_html()` - web sahifadagi barcha jadvallarni o'qib, `DataFrame1lardan iborat ro'yxat ko'rinishida qaytaradi.

# %%
import pandas as pd

# %%
data = pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %% [markdown]
# `data` tarkibida sahifadagi barcha jadvallar alohida `DataFrame` ko'rinishida saqlangan. Jadvallar sonini ko'rish uchun `len()` funksiyasiga murojaat qilamiz.

# %%
len(data)
# Out:
# 18

# %% [markdown]
# Yuqoridagi data tarkibida 16 ta DataFrame bor ekan. Alohida DataFramelarga indeks orqali murojaat qilishimiz mumkin.
# Ba'zida kerakli jadvlani topguncha bir necha indekslarni qarab chiqish talab qilinishi mumkin.

# %%
data[8]
# Out:
#     Year     Pop. ±% p.a.
# 0   2007  2157100  +0.77%
# 1   2008  2180000  +1.06%
# 2   2009  2206300  +1.21%
# 3   2010  2234300  +1.27%
# 4   2011  2296500  +2.78%
# 5   2012  2309300  +0.56%
# 6   2013  2340900  +1.37%
# 7   2014  2352900  +0.51%
# 8   2015  2371300  +0.78%
# 9   2016  2393200  +0.92%
# 10  2017  2424100  +1.29%
# 11  2018  2464900  +1.68%
# 12  2019  2509900  +1.83%
# 13  2020  2571700  +2.46%
# 14  2021  2694400  +4.77%

# %%
data[7]
# Out:
#     Year     Pop. ±% p.a.
# 0   1897   155673       —
# 1   1959   911930  +2.89%
# 2   1970  1384509  +3.87%
# 3   1979  1780002  +2.83%
# 4   1983  1902000  +1.67%
# 5   1989  2072459  +1.44%
# 6   1991  2130200  +1.38%
# 7   1995  2097400  −0.39%
# 8   2000  2142300  +0.42%
# 9   2001  2137900  −0.21%
# 10  2002  2136600  −0.06%
# 11  2003  2139200  +0.12%
# 12  2004  2135400  −0.18%
# 13  2005  2135700  +0.01%
# 14  2006  2140600  +0.23%

# %% [markdown]
# ### JSON format

# %% [markdown]
# JSON web orqali ma'lumotlarni uzatishda ishlatiluvchi eng mashhur formatlardan. JSON haqida Dasturlash Asoslari darsimizda batafsil ma'lumot berilgan: https://python.sariq.dev/files-exceptions/34-json

# %%
pd.read_json("universities_ranking.json")
# Out:
# --2025-05-15 12:11:10--  https://python.sariq.dev/files-exceptions/34-json
# Resolving python.sariq.dev (python.sariq.dev)... 104.18.40.47, 172.64.147.209, 2606:4700:4400::ac40:93d1, ...
# Connecting to python.sariq.dev (python.sariq.dev)|104.18.40.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘34-json’
#
# 34-json                 [  <=>               ] 628.85K  1.25MB/s    in 0.5s
#
# 2025-05-15 12:11:11 (1.25 MB/s) - ‘34-json’ saved [643946]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-c7771a5fa1bd> in <cell line: 0>()
#       1 get_ipython().system('wget https://python.sariq.dev/files-exceptions/34-json')
# ----> 2 pd.read_json("universities_ranking.json")
#
# ...

# %%
import requests, json
r = requests.get('http://api.nobelprize.org/v1/laureate.json')
data = r.json()
# data['laureates']
pd.DataFrame(data['laureates'],)
# Out:
#         id       firstname    surname        born        died  \
# 0        1  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10
# 1        2      Hendrik A.    Lorentz  1853-07-18  1928-02-04
# 2        3          Pieter     Zeeman  1865-05-25  1943-10-09
# 3        4           Henri  Becquerel  1852-12-15  1908-08-25
# 4        5          Pierre      Curie  1859-05-15  1906-04-19
# ...    ...             ...        ...         ...         ...
# 999   1042            Kang        Han  1970-11-27  0000-00-00
# 1000  1043  Nihon Hidankyo        NaN  1956-08-10  0000-00-00
# 1001  1044           Daron   Acemoglu  1967-09-03  0000-00-00
# 1002  1045           Simon    Johnson  1963-00-00  0000-00-00
# 1003  1046           James   Robinson  1960-00-00  0000-00-00
#
#                 bornCountry bornCountryCode                bornCity  \
# 0     Prussia (now Germany)              DE  Lennep (now Remscheid)
# 1           the Netherlands              NL                  Arnhem
# ...

# %% [markdown]
# ### Web API
# API haqida tushuncha hosil qilish uchun quyidagi 2 videoni ko'rishni tavsiya qilaman:
# - https://youtu.be/eID-mIzjb-E
# - https://youtu.be/QoKcBFLd2aE

# %%
r = requests.get("https://openlibrary.org/subjects/python.json?published_in=2015-2021")
pd.DataFrame(r.json()['works'])
# Out:
#                    key                                              title  \
# 0    /works/OL2784125W                                    Learning Python
# 1   /works/OL16976951W                                       Think Python
# 2   /works/OL17795703W                          Python for bioinformatics
# 3   /works/OL21349037W  Introduction to Python for Science and Enginee...
# 4   /works/OL15667639W                              Mining the Social Web
# 5   /works/OL15664278W                                  Head First Python
# 6    /works/OL6045694W                               Python in a Nutshell
# 7   /works/OL17422847W                           Python For Data Analysis
# 8   /works/OL23330617W                        Making music with computers
# 9   /works/OL21703042W                               Tour of Data Science
# 10  /works/OL19932156W                                      Fluent Python
# 11  /works/OL19548251W                                Python for Everyone
#
# ...
