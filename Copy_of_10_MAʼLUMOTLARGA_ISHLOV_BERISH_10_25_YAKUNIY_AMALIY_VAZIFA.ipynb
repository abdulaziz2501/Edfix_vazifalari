# %% [markdown]
# ![Imgur](https://i.imgur.com/h4PPC71.png)
# #**10-modul. Maʼlumotlarga ishlov berish. Fayllar va maʼlumotlar ombori**
#
# #**10.25. Modul boʻyicha yakuniy amaliy vazifa**
#
# **Amaliyotni bajargach, fayllar bilan ishlash, API va veb sahifalardan ma’lumot olish, SQL soʻrovlarini yozish va ma’lumotlar omboriga ma’lumot saqlash koʻnikmalariga ega boʻlasiz.**

# %% [markdown]
# #**Fayldan oʻqish va yozish**

# %% [markdown]
# #**1) CSV fayldan maʼlumotlarni o‘qish**
# * https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/data_date.csv havolasidagi maʼlumotlarni `df` oʻzgaruvchisiga saqlang!
# * `df` dan tasodifiy 10 ta qatorni ekranga chiqaring!

# %%
#javobni shu yerda yozing.
import pandas as pd

url = "https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/data_date.csv"
df = pd.read_csv(url)

df.sample(10)
# Out:
#              Date               Country                          Status  \
# 10446  2023-04-13               Estonia                            Good
# 1598   2022-07-27                Gambia                            Good
# 5626   2022-08-23            Tajikistan                        Moderate
# 10970  2023-05-11            Azerbaijan                            Good
# 2020   2022-07-30                 Gabon  Unhealthy for Sensitive Groups
# 48     2022-07-21                 Ghana  Unhealthy for Sensitive Groups
# 5634   2022-08-23  United Arab Emirates  Unhealthy for Sensitive Groups
# 12277  2023-07-13         New Caledonia                            Good
# 9690   2022-09-21                 Spain                        Moderate
# 9052   2022-09-17                France                            Good
#
#        AQI Value
# 10446         34
# 1598           6
# 5626          85
# 10970         35
# 2020         127
# 48           117
# 5634         114
# 12277         25
# 9690          71
# 9052          40

# %% [markdown]
# #**2) CSV fayliga yozish**
# * Quyidagi maʼlumotlardan dataframe yarating va uni `people_data.csv` fayliga saqlang.
# ```
# data = {
#     "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah", "Ivy", "Jack"],
#     "Age": [25, 30, 35, 40, 28, 33, 38, 45, 29, 31],
#     "City": ["Tashkent", "Samarkand", "Bukhara", "Andijan", "Nukus", "Khiva", "Namangan", "Fergana", "Jizzakh", "Termez"]
# }
# ```
# * Quyidagi maʼlumotlardan yana bir dataframe yarating va uni `people_data_2.csv` fayliga saqlang.
# ```
# {
# 'Name': ['Alice', 'Bob', 'Charlie'],
# 'Age': [25, 30, 35]
# }
# ```

# %%
#javobni shu yerda yozing.
data = {
  "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah", "Ivy", "Jack"],
  "Age": [25, 30, 35, 40, 28, 33, 38, 45, 29, 31],
  "City": ["Tashkent", "Samarkand", "Bukhara", "Andijan", "Nukus", "Khiva", "Namangan", "Fergana", "Jizzakh", "Termez"]
}

pd.DataFrame(data).to_csv("people_data.csv", index=False)
data2 = {
  'Name': ['Alice', 'Bob', 'Charlie'],
  'Age': [25, 30, 35]
}

pd.DataFrame(data2).to_csv("people_data2.csv", index=False)

# %% [markdown]
# #**3) HDF5 formati bilan ishlash**
# * Yuqorida yaratgan dataframeʼlaringizni `people.h5` faylida saqlang.
# * `people.h5` faylidagi barcha jadvallarni oʻqing!

# %%
#javobni shu yerda yozing.
pd.read_csv("people_data.csv").to_hdf("people.h5", key="data1", mode="w")
pd.read_csv("people_data2.csv").to_hdf("people.h5", key="data2", mode="a")
hdf = pd.HDFStore("people.h5")
hdf.close()

# %%
df1 = pd.read_hdf("people.h5", key="data1")
df1
# Out:
#       Name  Age       City
# 0    Alice   25   Tashkent
# 1      Bob   30  Samarkand
# 2  Charlie   35    Bukhara
# 3    David   40    Andijan
# 4      Eve   28      Nukus
# 5    Frank   33      Khiva
# 6    Grace   38   Namangan
# 7   Hannah   45    Fergana
# 8      Ivy   29    Jizzakh
# 9     Jack   31     Termez

# %%
df2 = pd.read_hdf("people.h5", key="data2")
df2
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
# #**4) JSON fayllar bilan ishlash**
# 1. Quyidagi maʼlumotlarni dataframe koʻrinishida oʻqing va uni `data.json` fayliga yozing!
# ```
# data = {
#     "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah", "Ivy", "Jack"],
#     "Age": [25, 30, 35, 40, 28, 33, 38, 45, 29, 31],
#     "City": ["Tashkent", "Samarkand", "Bukhara", "Andijan", "Nukus", "Khiva", "Namangan", "Fergana", "Jizzakh", "Termez"]
# }
# ```

# %%
#javobni shu yerda yozing.
data = {
 "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah", "Ivy", "Jack"],
 "Age": [25, 30, 35, 40, 28, 33, 38, 45, 29, 31],
 "City": ["Tashkent", "Samarkand", "Bukhara", "Andijan", "Nukus", "Khiva", "Namangan", "Fergana", "Jizzakh", "Termez"]
}
pd.DataFrame(data).to_json("data.json", index=False)

# %% [markdown]
# #**5) APIʼlar bilan ishlash**
# 1. Quyida berilgan API 17 mingdan ortiq kriptovalyutalarning dollarga nisbatan narxi haqidagi maʼlumotlarni saqlaydi. Siz esa endi:
#   * API orqali barcha maʼlumotlarni yigʻib oling;
#   * ularni dataframe koʻrinishida saqlang;
#   * maʼlumotlar boshidan 5 ta qatorni ekranga chiqaring;
#   * maʼlumotlar ichidan `bitcoin` ni izlab toping!

# %%
coins_url = "https://api.coingecko.com/api/v3/coins/list"
#javobni shu yerda yozing.
import requests
import pandas as pd


response = requests.get(coins_url)
data = response.json()

df = pd.DataFrame(data)

df.head()
# Out:
#             id symbol          name
# 0            _    gib    ༼ つ ◕_◕ ༽つ
# 1  000-capital    000   000 Capital
# 2       01coin    zoc        01coin
# 3       0chain    zcn           Zus
# 4         0dog   0dog  Bitcoin Dogs

# %%
df[df["id"] == "bitcoin"]
# Out:
#            id symbol     name
# 2020  bitcoin    btc  Bitcoin

# %% [markdown]
# #**6) APIʼlar bilan ishlash**
# 1. Yuqorida berilgan kriptovalyuta maʼlumotlaridan `id` ustunini roʻyxat koʻrinishida saqlang va bu roʻyxatga `coin_ids` deb nom bering.
# 2. https://api.coingecko.com/api/v3/simple/price?ids={coin_ids}&vs_currencies=usd havolasi orqali kriptovalyutalarning `usd` ga nisbatini oling (birinchi 100 ta maʼlumotni olish yetarli).
# 3. 2-shartda berilgan link orqali olingan maʼlumotlarni dataframe koʻrinishida saqlang. Bunda uning indeksi va `usd` ustuni boʻlsin. `index` -> kriptovalyutalar nomi, `usd` -> narxi
#
# #**💡Ishora:** linkdagi `{coin_ids}` oʻzgaruvchi sifatida yozilgan. Siz ham 1-shartda saqlagan `coin_ids` oʻzgaruvchingizni shu qismda yozib keting!

# %%
coin_ids = df['id'].head(100).tolist()
ids_string = ",".join(coin_ids)
price_url = f"https://api.coingecko.com/api/v3/simple/price?ids={ids_string}&vs_currencies=usd"

#javobni shu yerda yozing.

price_response = requests.get(price_url)
price_data = price_response.json()

price_df = pd.DataFrame(price_data).T
price_df.columns = ["usd"]

price_df.head()
# Out:
#                   usd
# _            0.002062
# 000-capital  0.000463
# 01coin       0.000113
# 0chain       0.005936
# 0dog         0.000053

# %% [markdown]
# #**7) Veb sahifadan oʻqish**
# 1. Pandas yordamida veb sahifadagi jadvalni yuklab oling.
# 2. Ma’lumotlarni dataframe ko‘rinishida chiqaring.
# 3. Agar sahifada bir nechta jadval bo‘lsa, eng muhimini tanlang.
# 4. Ma’lumotni tozalang (bo‘sh qatorlarni olib tashlang, kerakli ustunlarni tanlang).
# 5. Natijani CSV faylga saqlang.
#
# ***Eslatma: manba sifatida oʻzingiz istagan veb sahifani tanlang. Bu vazifada mustaqil izlanishni oʻrganasiz!***

# %%
#javobni shu yerda yozing.
import pandas as pd

url = "https://uz.wikipedia.org/wiki/Toshkent"

tables = pd.read_html(url)

print(f"{len(tables)} ta jadval topildi.")
# Out:
# 20 ta jadval topildi.

# %%
df = tables[8]
df.head()
# Out:
#                                                    0  \
# 0  YilAholi±% y.oʻ.s.1897 155 673— 1950 755 000+3...
# 1                                                Yil
# 2                                               1897
# 3                                               1950
# 4                                               1959
#
#                                                    1           2
# 0  YilAholi±% y.oʻ.s.2005 2 135 700+0.01%2006 2 1...         NaN
# 1                                              Aholi  ±% y.oʻ.s.
# 2                                            155 673           —
# 3                                            755 000      +3.02%
# 4                                            911 930      +2.12%

# %%
df = df.dropna()
df.head()
# Out:
#       0        1           2
# 1   Yil    Aholi  ±% y.oʻ.s.
# 2  1897  155 673           —
# 3  1950  755 000      +3.02%
# 4  1959  911 930      +2.12%
# 5  1960  964 000      +5.71%

# %%
df.to_csv("toshkent_jadval.csv", index=False)

# %% [markdown]
# # **Maʼlumotlar ombori bilan ishlash**

# %% [markdown]
# #**8) Maʼlumotlar omborini yuklash va ulanish**
# 1. https://github.com/alishermutalov/praktikum-datasets/blob/praktikum/chinook.db havolasi orqali maʼlumotlar omborini yuklab oling.
# 2. Yuklab olingan maʼlumotlar omboriga sqlite3 moduli yordamida **ulaning**.

# %%
# !wget https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# !unzip "chinook.zip"
# Out:
# --2025-06-12 19:06:52--  https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Resolving www.sqlitetutorial.net (www.sqlitetutorial.net)... 172.67.172.250, 104.21.30.141, 2606:4700:3037::6815:1e8d, ...
# Connecting to www.sqlitetutorial.net (www.sqlitetutorial.net)|172.67.172.250|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305596 (298K) [application/zip]
# Saving to: ‘chinook.zip’
#
# chinook.zip         100%[===================>] 298.43K   828KB/s    in 0.4s
#
# 2025-06-12 19:06:53 (828 KB/s) - ‘chinook.zip’ saved [305596/305596]
#
# Archive:  chinook.zip
#   inflating: chinook.db

# %%
#javobni shu yerda yozing.
import sqlite3

conn = sqlite3.connect("/content/chinook.db")
cursor = conn.cursor()

# %% [markdown]
# #**9) Maʼlumotlar omboriga soʻrov yuborish**
# 1. Jadvallar roʻyxatini koʻring. Ularning ichida `albums` jadvali boʻlsa, shu jadvaldagi barcha maʼlumotlarni (qatorlarni) ekranga chiqaring.
# 2. Qatorlar soni nechta ekanini aniqlab, uni ham ekranga chiqaring.
# 3.`albums` jadvalining ustunlari haqidagi maʼlumotlarni ekranga chiqaring.

# %%
#javobni shu yerda yozing.
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
tables
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',),
#  ('users',),
#  ('sales',)]

# %%
df_albums = pd.read_sql("SELECT * FROM albums", conn)
print(df_albums)
print(f"\nQatorlar soni: {len(df_albums)}")

# %%
cursor.execute("PRAGMA table_info(albums);")
columns_info = cursor.fetchall()
columns_info
# Out:
# [(0, 'AlbumId', 'INTEGER', 1, None, 1),
#  (1, 'Title', 'NVARCHAR(160)', 1, None, 0),
#  (2, 'ArtistId', 'INTEGER', 1, None, 0)]

# %% [markdown]
# #**10) SQL to DataFrame**
# 1. `albums` jadvalini `pandas.DataFrame` ga oʻtkazing!

# %%
#javobni shu yerda yozing.
df_albums = pd.read_sql("SELECT * FROM albums", conn)
df_albums.head()
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %% [markdown]
# #**11)**  `chinook.db` maʼlumotlar omboridan `tracks` jadvalining birinchi 10 ta qatorini ekranga chiqaring
#
# #💡Ishora: LIMIT

# %%
#javobni shu yerda yozing.
cursor.execute("SELECT * FROM tracks LIMIT 10;")
tracks = cursor.fetchall()
tracks
# Out:
# [(1,
#   'For Those About To Rock (We Salute You)',
#   1,
#   1,
#   1,
#   'Angus Young, Malcolm Young, Brian Johnson',
#   343719,
#   11170334,
#   0.99),
#  (2, 'Balls to the Wall', 2, 2, 1, None, 342562, 5510424, 0.99),
#  (3,
#   'Fast As a Shark',
#   3,
#   2,
#   1,
#   'F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman',
#   230619,
#   3990994,
#   0.99),
#  (4,
#   'Restless and Wild',
#   3,
#   2,
#   1,
#   'F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman',
#   252051,
#   4331779,
#   0.99),
#  (5,
#   'Princess of the Dawn',
#   3,
#   2,
#   1,
#   'Deaffy & R.A. Smith-Diesel',
#   375418,
#   6290521,
#   0.99),
#  (6,
#   'Put The Finger On You',
#   1,
#   1,
#   1,
#   'Angus Young, Malcolm Young, Brian Johnson',
#   205662,
#   6713451,
#   0.99),
#  (7,
#   "Let's Get It Up",
#   1,
#   1,
#   1,
#   'Angus Young, Malcolm Young, Brian Johnson',
#   233926,
#   7636561,
#   0.99),
#  (8,
#   'Inject The Venom',
#   1,
#   1,
#   1,
#   'Angus Young, Malcolm Young, Brian Johnson',
#   210834,
#   6852860,
#   0.99),
#  (9,
#   'Snowballed',
#   1,
#   1,
#   1,
#   'Angus Young, Malcolm Young, Brian Johnson',
#   203102,
#   6599424,
#   0.99),
#  (10,
#   'Evil Walks',
#   1,
#   1,
#   1,
#   'Angus Young, Malcolm Young, Brian Johnson',
#   263497,
#   8611245,
#   0.99)]

# %% [markdown]
# #**12)**`tracks` jadvalidan faqat `Name`, `Composer` ustunlarini tanlab oling!

# %%
#javobni shu yerda yozing.
cursor.execute("SELECT Name, Composer FROM tracks LIMIT 5;")
tracks = cursor.fetchall()
tracks
# Out:
# [('For Those About To Rock (We Salute You)',
#   'Angus Young, Malcolm Young, Brian Johnson'),
#  ('Balls to the Wall', None),
#  ('Fast As a Shark', 'F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman'),
#  ('Restless and Wild',
#   'F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman'),
#  ('Princess of the Dawn', 'Deaffy & R.A. Smith-Diesel')]

# %% [markdown]
# #**13) ORDER BY , DISTINCT**
# * `tracks` jadvalidagi takrorlanmaydigan `GenreId` qiymatlarini oling.
# * `tracks` jadvalidagi treklarni `Milliseconds` ustuni bo‘yicha kamayish tartibida saralang.
#
# #💡Ishora: ORDER BY , DISTINCT

# %%
#javobni shu yerda yozing.

distinct_genres = pd.read_sql("SELECT DISTINCT GenreId FROM tracks", conn)
distinct_genres.head()
# Out:
#    GenreId
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
sorted_tracks = pd.read_sql("SELECT * FROM tracks ORDER BY Milliseconds DESC", conn)
sorted_tracks.head()
# Out:
#    TrackId                         Name  AlbumId  MediaTypeId  GenreId  \
# 0     2820       Occupation / Precipice      227            3       19
# 1     3224      Through a Looking Glass      229            3       21
# 2     3244  Greetings from Earth, Pt. 1      253            3       20
# 3     3242      The Man With Nine Lives      253            3       20
# 4     3227  Battlestar Galactica, Pt. 2      253            3       20
#
#   Composer  Milliseconds       Bytes  UnitPrice
# 0     None       5286953  1054423946       1.99
# 1     None       5088838  1059546140       1.99
# 2     None       2960293   536824558       1.99
# 3     None       2956998   577829804       1.99
# 4     None       2956081   521387924       1.99

# %% [markdown]
# #**14) Filtering**
#  * `invoices` jadvalidan `Total` summasi 10 dan katta bo‘lgan maʼlumotlarni tanlang.
#
# # 💡Ishora: WHERE

# %%
#javobni shu yerda yozing.
invoices = pd.read_sql("SELECT * FROM invoices WHERE Total > 10", conn)
invoices.head()
# Out:
#    InvoiceId  CustomerId          InvoiceDate           BillingAddress  \
# 0          5          23  2009-01-11 00:00:00          69 Salem Street
# 1         12           2  2009-02-11 00:00:00  Theodor-Heuss-Straße 34
# 2         19          40  2009-03-14 00:00:00           8, Rue Hanovre
# 3         26          19  2009-04-14 00:00:00          1 Infinite Loop
# 4         33          57  2009-05-15 00:00:00          Calle Lira, 198
#
#   BillingCity BillingState BillingCountry BillingPostalCode  Total
# 0      Boston           MA            USA              2113  13.86
# 1   Stuttgart         None        Germany             70174  13.86
# 2       Paris         None         France             75002  13.86
# 3   Cupertino           CA            USA             95014  13.86
# 4    Santiago         None          Chile              None  13.86

# %% [markdown]
# #**15) CREATE and INSERT**
# * `chinook.db` maʼlumotlar omboriga `users` jadvali yarating. Jadval maydonlari (ustunlar):
#   * `id`
#   * `name`
#   * `birth_date`
# * Yaratilgan `users` jadvaliga quyidagi maʼlumotlarni qoʻshing:
#
#     * ```
#     [
#     ('Alice', 25), ('Bob', 30), ('Charlie', 35), ('David', 28), ('Eve', 22),
#     ('Frank', 40), ('Grace', 27), ('Hannah', 32), ('Ivy', 29), ('Jack', 31),
#     ('Kevin', 33), ('Liam', 26), ('Mia', 24), ('Noah', 36), ('Olivia', 23),
#     ('Peter', 39), ('Quinn', 37), ('Rachel', 34), ('Samuel', 41), ('Tina', 21)
# ]
#  ```
#
# #💡Ishora: CREATE TABLE, INSERT

# %%
#javobni shu yerda yozing.
cursor.execute("CREATE TABLE IF NOT EXISTS users (id INTEGER PRIMARY KEY AUTOINCREMENT, name TEXT, birth_date INTEGER)")
conn.commit()

# %%
data = [
    ('Alice', 25), ('Bob', 30), ('Charlie', 35), ('David', 28), ('Eve', 22),
    ('Frank', 40), ('Grace', 27), ('Hannah', 32), ('Ivy', 29), ('Jack', 31),
    ('Kevin', 33), ('Liam', 26), ('Mia', 24), ('Noah', 36), ('Olivia', 23),
    ('Peter', 39), ('Quinn', 37), ('Rachel', 34), ('Samuel', 41), ('Tina', 21)
]
cursor.executemany("INSERT INTO users (name, birth_date) VALUES (?, ?)", data)
conn.commit()

# %% [markdown]
# #**16) UPDATE and DELETE**
# * `users` jadvalidagi Alice ismli foydalanuvchining yoshini yangilang.
# * `users` jadvalidan Alice ismli foydalanuvchini o‘chiring.

# %%
#javobni shu yerda yozing.
cursor.execute("UPDATE users SET birth_date = 26 WHERE name = 'Alice'")
conn.commit()
# Out:
# []

# %%
cursor.execute("DELETE FROM users WHERE name = 'Alice'")
conn.commit()

# %% [markdown]
# #**17) f-string yordamida SQL komandalarini yozish**
# * `customers` jadvalidan `FirstName` va `LastName` bo‘yicha qidiruv qiladigan f-string yozing.

# %%
#javobni shu yerda yozing.
first_name = input('First name : ')
last_name = input('Last name  : ')

query = f"""
SELECT * FROM customers
WHERE FirstName = '{first_name}' AND LastName = '{last_name}';
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# First name : Astrid
# Last namre  : Gruber
# (7, 'Astrid', 'Gruber', None, 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', None, 'Austria', '1010', '+43 01 5134505', None, 'astrid.gruber@apple.at', 5)

# %%
cursor.execute('SELECT * FROM customers LIMIT 5;')
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# (1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3)
# (2, 'Leonie', 'Köhler', None, 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', '+49 0711 2842222', None, 'leonekohler@surfeu.de', 5)
# (3, 'François', 'Tremblay', None, '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', '+1 (514) 721-4711', None, 'ftremblay@gmail.com', 3)
# (4, 'Bjørn', 'Hansen', None, 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', '+47 22 44 22 22', None, 'bjorn.hansen@yahoo.no', 4)
# (5, 'František', 'Wichterlová', 'JetBrains s.r.o.', 'Klanova 9/506', 'Prague', None, 'Czech Republic', '14700', '+420 2 4172 5555', '+420 2 4172 5555', 'frantisekw@jetbrains.com', 4)

# %% [markdown]
# #**18)  AND and OR operators**
#
# * `invoices` jadvalidan `BillingCountry` Germaniya yoki Fransiya boʻlgan va `Total` summasi 5 dan katta bo‘lgan kerakli qatorlarni tanlang.
#
# #💡Ishora: AND, OR

# %%
#javobni shu yerda yozing.
query = """
SELECT * FROM invoices
WHERE (BillingCountry = 'Germany' OR BillingCountry = 'France') AND Total > 5;
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# (12, 2, '2009-02-11 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', 13.86)
# (19, 40, '2009-03-14 00:00:00', '8, Rue Hanovre', 'Paris', None, 'France', '75002', 13.86)
# (31, 42, '2009-05-07 00:00:00', '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', 5.94)
# (40, 36, '2009-06-15 00:00:00', 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', 13.86)
# (52, 38, '2009-08-08 00:00:00', 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', 5.94)
# (67, 2, '2009-10-12 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', 8.91)
# (74, 40, '2009-11-12 00:00:00', '8, Rue Hanovre', 'Paris', None, 'France', '75002', 8.91)
# (95, 36, '2010-02-13 00:00:00', 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', 8.91)
# (117, 41, '2010-05-22 00:00:00', '11, Place Bellecour', 'Lyon', None, 'France', '69002', 13.86)
# (129, 43, '2010-07-15 00:00:00', '68, Rue Jouvence', 'Dijon', None, 'France', '21000', 5.94)
# (138, 37, '2010-08-23 00:00:00', 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', 13.86)
# (150, 39, '2010-10-16 00:00:00', '4, Rue Milton', 'Paris', None, 'France', '75009', 5.94)
# (172, 41, '2011-01-20 00:00:00', '11, Place Bellecour', 'Lyon', None, 'France', '69002', 8.91)
# (193, 37, '2011-04-23 00:00:00', 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', 14.91)
# (215, 42, '2011-07-30 00:00:00', '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', 13.86)
# (236, 38, '2011-10-31 00:00:00', 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', 13.86)
# (241, 2, '2011-11-23 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', 5.94)
# (248, 40, '2011-12-24 00:00:00', '8, Rue Hanovre', 'Paris', None, 'France', '75002', 5.94)
# (269, 36, '2012-03-26 00:00:00', 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', 5.94)
# (270, 42, '2012-03-29 00:00:00', '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', 8.91)
# (291, 38, '2012-06-30 00:00:00', 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', 8.91)
# (313, 43, '2012-10-06 00:00:00', '68, Rue Jouvence', 'Dijon', None, 'France', '21000', 16.86)
# (334, 39, '2013-01-07 00:00:00', '4, Rue Milton', 'Paris', None, 'France', '75009', 13.86)
# (346, 41, '2013-03-02 00:00:00', '11, Place Bellecour', 'Lyon', None, 'France', '69002', 5.94)
# (367, 37, '2013-06-03 00:00:00', 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', 5.94)
# (368, 43, '2013-06-06 00:00:00', '68, Rue Jouvence', 'Dijon', None, 'France', '21000', 8.91)
# (389, 39, '2013-09-07 00:00:00', '4, Rue Milton', 'Paris', None, 'France', '75009', 8.91)

# %% [markdown]
# #**19) BETWEEN and LIKE**
#
# * `invoices` jadvalidan `Total` summasi 5 dan 15 gacha bo‘lgan qatorlarni tanlang.
# * `customers` jadvalidan ismi `A` harfi bilan boshlanadigan foydalanuvchilarni tanlang.

# %%
#javobni shu yerda yozing.
query = """
SELECT * FROM invoices
WHERE Total BETWEEN 5 AND 15 LIMIT 5;
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# (3, 8, '2009-01-03 00:00:00', 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', 5.94)
# (4, 14, '2009-01-06 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 8.91)
# (5, 23, '2009-01-11 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 13.86)
# (10, 46, '2009-02-03 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, 5.94)
# (11, 52, '2009-02-06 00:00:00', '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', 8.91)

# %%
query = """
SELECT * FROM customers
WHERE FirstName LIKE 'A%';
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# (7, 'Astrid', 'Gruber', None, 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', None, 'Austria', '1010', '+43 01 5134505', None, 'astrid.gruber@apple.at', 5)
# (11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5)
# (32, 'Aaron', 'Mitchell', None, '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', '+1 (204) 452-6452', None, 'aaronmitchell@yahoo.ca', 4)

# %% [markdown]
# #**20) DataFrame to SQL**
# * Quyidagi maʼlumotlardan dataframe yarating.
#   ```
#   sales_data = {
#     "sale_id": list(range(1, 21)),  # 1 dan 20 gacha boʻlgan unikal IDʼlar
#     "product_name": [
#         "Laptop", "Smartphone", "Tablet", "Headphones", "Smartwatch",
#         "Monitor", "Keyboard", "Mouse", "Printer", "Camera",
#         "Speaker", "Game Console", "TV", "Router", "Power Bank",
#         "Hard Drive", "USB Flash", "Graphics Card", "Microphone", "VR Headset"
#     ],
#     "quantity": [2, 5, 3, 10, 4, 6, 8, 12, 3, 5, 7, 9, 4, 2, 11, 6, 15, 1, 3, 2],
#     "price": [1200, 800, 450, 200, 300, 500, 100, 50, 250, 700,
#               150, 400, 1000, 90, 60, 110, 30, 1500, 80, 600],
#     "sale_date": [
#         "2025-03-01", "2025-03-02", "2025-03-03", "2025-03-04", "2025-03-05",
#         "2025-03-06", "2025-03-07", "2025-03-08", "2025-03-09", "2025-03-10",
#         "2025-03-11", "2025-03-12", "2025-03-13", "2025-03-14", "2025-03-15",
#         "2025-03-16", "2025-03-17", "2025-03-18", "2025-03-19", "2025-03-20"
#     ]
# }
# ```
# *Yuqoridagi maʼlumotlar asosida yaratgan dataframeʼingizdan SQL jadvali tuzing va uni `sales` deb nomlang.

# %%
#javobni shu yerda yozing.
sales_data = {
    "sale_id": list(range(1, 21)),
    "product_name": [
        "Laptop", "Smartphone", "Tablet", "Headphones", "Smartwatch",
        "Monitor", "Keyboard", "Mouse", "Printer", "Camera",
        "Speaker", "Game Console", "TV", "Router", "Power Bank",
        "Hard Drive", "USB Flash", "Graphics Card", "Microphone", "VR Headset"
    ],
    "quantity": [2, 5, 3, 10, 4, 6, 8, 12, 3, 5, 7, 9, 4, 2, 11, 6, 15, 1, 3, 2],
    "price": [1200, 800, 450, 200, 300, 500, 100, 50, 250, 700,
              150, 400, 1000, 90, 60, 110, 30, 1500, 80, 600],
    "sale_date": [
        "2025-03-01", "2025-03-02", "2025-03-03", "2025-03-04", "2025-03-05",
        "2025-03-06", "2025-03-07", "2025-03-08", "2025-03-09", "2025-03-10",
        "2025-03-11", "2025-03-12", "2025-03-13", "2025-03-14", "2025-03-15",
        "2025-03-16", "2025-03-17", "2025-03-18", "2025-03-19", "2025-03-20"
    ]
}
df.to_sql("sales", conn, index=False)
df = pd.DataFrame(sales_data)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-1208779758> in <cell line: 0>()
#      18     ]
#      19 }
# ---> 20 df.to_sql("sales", conn, index=False)
#      21 df = pd.DataFrame(sales_data)
#      22 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3085         from pandas.io import sql
#    3086
# -> 3087         return sql.to_sql(
#    3088             self,
#    3089             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     840
#     841     with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842         return pandas_sql.to_sql(
#     843             frame,
#     844             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2848             dtype=dtype,
#    2849         )
# -> 2850         table.create()
#    2851         return table.insert(chunksize, method)
#    2852
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in create(self)
#     984         if self.exists():
#     985             if self.if_exists == "fail":
# --> 986                 raise ValueError(f"Table '{self.name}' already exists.")
#     987             if self.if_exists == "replace":
#     988                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'sales' already exists.
